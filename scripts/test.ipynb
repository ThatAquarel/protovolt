# %%
import pyvisa

r = pyvisa.ResourceManager()
i = r.open_resource("ASRL/dev/ttyACM5::INSTR", read_termination="\n", write_termination="\n")

# %%
i.query("*IDN?")
# Out:
# 'FBRD Inc.,ProtoV MINI,00000011,0.1.0,A.1'

# %%
i.query("SYST:ERR?")
# Out:
# '0,"No error"'

# %%
i.query("TELEM?")
# Out:
# '31.037,30.927,32.300,PD,20.000,5.000,1,1'

# %%
i.write("OUTP CH1,OFF")

# %%
i.query("TPS55289:REG? CHA")

# %%
i.query("INA226:REG? CHB")

# %%
i.query("DIAG?")
# Out:
# '1,1'

# %%
i.query("CH1:MODE?"), i.query("CH2:MODE?")
# Out:
# ('TEMP', 'CV')

# %%
i.close()

# %%
# Hue u8 COLR smoke test (CH1 default 0, CH2 default 170)
i.query("CH1:COLR?"), i.query("CH2:COLR?")

# %%
i.query("LCD:BRIG?")

# %%
i.write("LCD:BRIG 255")

# %%
i.query("LED:BRIG?")

# %%
i.write("LED:BRIG 12")

# %%
i.write("CH1:COLR 234,67,53")
